# %%
#importing pandas library
import pandas as pd

# %%
#loading dataset using pandas
dataframe=pd.read_csv("telecom_churn.csv")

# %%
#checking first 5 rows using head() method
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
#checking datatype of every column by using info() method
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
#check no. of rows and columns- shape
dataframe.shape
# Out:
# (3333, 20)

# %%
#list down all columns of datafile
dataframe.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#Describing the dataset -statistical view
dataframe.describe()
# Out:
#        Account length    Area code  ...  Total intl charge  Customer service calls
# count     3333.000000  3333.000000  ...        3333.000000             3333.000000
# mean       101.064806   437.182418  ...           2.764581                1.562856
# std         39.822106    42.371290  ...           0.753773                1.315491
# min          1.000000   408.000000  ...           0.000000                0.000000
# 25%         74.000000   408.000000  ...           2.300000                1.000000
# 50%        101.000000   415.000000  ...           2.780000                1.000000
# 75%        127.000000   510.000000  ...           3.270000                2.000000
# max        243.000000   510.000000  ...           5.400000                9.000000
#
# [8 rows x 16 columns]

# %%
#selecting a particular column
dataframe[["Area code"]]
# Out:
#       Area code
# 0           415
# 1           415
# 2           415
# 3           408
# 4           415
# ...         ...
# 3328        415
# 3329        415
# 3330        510
# 3331        510
# 3332        415
#
# [3333 rows x 1 columns]

# %%
#selecting a particular row
dataframe.iloc[1]
# Out:
# State                        OH
# Account length              107
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        26
# Total day minutes         161.6
# Total day calls             123
# Total day charge          27.47
# Total eve minutes         195.5
# Total eve calls             103
# Total eve charge          16.62
# Total night minutes       254.4
# Total night calls           103
# Total night charge        11.45
# Total intl minutes         13.7
# Total intl calls              3
# Total intl charge           3.7
# Customer service calls        1
# Churn                     False
# Name: 1, dtype: object

# %%
dataframe.iloc[0]
# Out:
# State                        KS
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         265.1
# Total day calls             110
# Total day charge          45.07
# Total eve minutes         197.4
# Total eve calls              99
# Total eve charge          16.78
# Total night minutes       244.7
# Total night calls            91
# Total night charge        11.01
# Total intl minutes           10
# Total intl calls              3
# Total intl charge           2.7
# Customer service calls        1
# Churn                     False
# Name: 0, dtype: object

# %%
dataframe.iloc[2]
# Out:
# State                        NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls             114
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls             110
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls           104
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls        0
# Churn                     False
# Name: 2, dtype: object

# %% [markdown]
# ##Combining different methods in one cell

# %%
#selecting a particular row of particular column
dataframe["Total day minutes"].iloc[1]
# Out:
# 161.6

# %%
dataframe["Total day minutes"].head()
# Out:
# 0    265.1
# 1    161.6
# 2    243.4
# 3    299.4
# 4    166.7
# Name: Total day minutes, dtype: float64

# %% [markdown]
# ##Count unique values in a particular column

# %%
dataframe["Churn"].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
dataframe["State"].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# OH     78
# OR     78
# WI     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# KS     70
# MD     70
# NJ     68
# NC     68
# MT     68
# NV     66
# WA     66
# CO     66
# MA     65
# RI     65
# MS     65
# AZ     64
# MO     63
# FL     63
# ND     62
# NM     62
# ME     62
# OK     61
# DE     61
# NE     61
# SD     60
# SC     60
# KY     59
# IL     58
# NH     56
# AR     55
# DC     54
# GA     54
# TN     53
# HI     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %% [markdown]
# ##Sorting

# %%
#arranging dataset acc ascending of a column

# %%
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
dataframe.sort_values(by="Total day minutes").head()
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 1345    SD              98  ...                       4   True
# 1397    VT             101  ...                       1  False
# 2736    OK             127  ...                       3  False
# 2753    OH             134  ...                       2  False
# 1986    WI              70  ...                       0  False
#
# [5 rows x 20 columns]

# %%
#descending order
dataframe.sort_values(by="Total day minutes", ascending=False).head()
# Out:
#      State  Account length  ...  Customer service calls Churn
# 365     CO             154  ...                       1  True
# 985     NY              64  ...                       1  True
# 2594    OH             115  ...                       1  True
# 156     OH              83  ...                       0  True
# 605     MO             112  ...                       2  True
#
# [5 rows x 20 columns]

# %% [markdown]
# ##Retrieving stats

# %%
#mean of any particular column
dataframe["Total day minutes"].mean()
# Out:
# 179.77509750975116

# %% [markdown]
# ##Selecting dataframe according to a particular condition

# %%
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
#Selecting particular data from the dataframe
dataframe[dataframe["Customer service calls"]==1]
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 0       KS             128  ...                       1  False
# 1       OH             107  ...                       1  False
# 8       LA             117  ...                       1  False
# 12      IA             168  ...                       1  False
# 16      ID              85  ...                       1  False
# ...    ...             ...  ...                     ...    ...
# 3313    ID             127  ...                       1  False
# 3314    MO              89  ...                       1  False
# 3317    SD             163  ...                       1  False
# 3324    WV             159  ...                       1  False
# 3326    OH              96  ...                       1  False
#
# [1181 rows x 20 columns]

# %%
dataframe[dataframe["State"]=="OH"]
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 1       OH             107  ...                       1  False
# 3       OH              84  ...                       2  False
# 152     OH              65  ...                       1  False
# 156     OH              83  ...                       0   True
# 231     OH              63  ...                       1  False
# ...    ...             ...  ...                     ...    ...
# 3249    OH             160  ...                       0  False
# 3251    OH              88  ...                       2  False
# 3286    OH             106  ...                       0  False
# 3325    OH              78  ...                       2  False
# 3326    OH              96  ...                       1  False
#
# [78 rows x 20 columns]

# %%
dataframe[dataframe["Number vmail messages"]>20]
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 0       KS             128  ...                       1  False
# 1       OH             107  ...                       1  False
# 6       MA             121  ...                       3  False
# 9       WV             141  ...                       0  False
# 16      ID              85  ...                       1  False
# ...    ...             ...  ...                     ...    ...
# 3305    IN              58  ...                       2  False
# 3306    AL             106  ...                       1  False
# 3316    MS             103  ...                       0  False
# 3328    AZ             192  ...                       2  False
# 3332    TN              74  ...                       0  False
#
# [813 rows x 20 columns]

# %% [markdown]
# ##Type coversion

# %%
# Changing the datatype
# .astype(datatype_name)
dataframe["Churn"].astype("int64")
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
dataframe["Churn"]=dataframe["Churn"].astype("int64")

# %%
dataframe.head()
# Out:
#   State  Account length  Area code  ... Customer service calls Churn  churn
# 0    KS             128        415  ...                      1     0      0
# 1    OH             107        415  ...                      1     0      0
# 2    NJ             137        415  ...                      0     0      0
# 3    OH              84        408  ...                      2     0      0
# 4    OK              75        415  ...                      3     0      0
#
# [5 rows x 21 columns]

# %%
#deletes the particular column
dataframe.drop("churn",1)
# Out:
#      State  Account length  ...  Customer service calls Churn
# 0       KS             128  ...                       1     0
# 1       OH             107  ...                       1     0
# 2       NJ             137  ...                       0     0
# 3       OH              84  ...                       2     0
# 4       OK              75  ...                       3     0
# ...    ...             ...  ...                     ...   ...
# 3328    AZ             192  ...                       2     0
# 3329    WV              68  ...                       3     0
# 3330    RI              28  ...                       2     0
# 3331    CT             184  ...                       2     0
# 3332    TN              74  ...                       0     0
#
# [3333 rows x 20 columns]

# %%
#display total unique values
dataframe["Churn"].unique()
# Out:
# array([0, 1])

# %%
dataframe["State"].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
#object to int coversion gives error
dataframe["International plan"].astype("int64")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-e9d6592f578d> in <module>()
# ----> 1 dataframe["International plan"].astype("int64")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %% [markdown]
# ##Visualisation

# %%
#Matplotlib/Seaborn: Used for visualizations

# %%
import seaborn as sns

# %%
# countplot: value_counts() in visual form. Bar Graph of the count
# Syntax countplot: sns.countplot("Column_Name", data=dataset_name)

# %%
sns.countplot("Churn",data=dataframe)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#hue: for scaling purpose in chart
sns.countplot("Churn",data=dataframe,hue="Churn")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot("International plan", data=dataframe, hue="International plan")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot("Voice mail plan", data=dataframe, hue="Voice mail plan")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# countplot: shows relation between any two columns
# Syntax countplot: sns.lineplot(x="Column_name", y="Column_name", data=dataset_name)

# %%
dataframe.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn', 'churn'],
#       dtype='object')

# %%
sns.lineplot(x="International plan",y="Churn",data=dataframe)

# %%
sns.lineplot(x="Voice mail plan",y="Churn",data=dataframe)

# %%
sns.lineplot(x="Number vmail messages",y="Total day calls",data=dataframe)

# %% [markdown]
# ##Missing values

# %%
#in python missing values are represented by NaN or None
dataframe.isnull()
# Out:
#       State  Account length  Area code  ...  Customer service calls  Churn  churn
# 0     False           False      False  ...                   False  False  False
# 1     False           False      False  ...                   False  False  False
# 2     False           False      False  ...                   False  False  False
# 3     False           False      False  ...                   False  False  False
# 4     False           False      False  ...                   False  False  False
# ...     ...             ...        ...  ...                     ...    ...    ...
# 3328  False           False      False  ...                   False  False  False
# 3329  False           False      False  ...                   False  False  False
# 3330  False           False      False  ...                   False  False  False
# 3331  False           False      False  ...                   False  False  False
# ...

# %%
dataframe.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# churn                     0
# dtype: int64

# %%
#to drop rows having missing values
#dropna(): drops all the rows having any missing value
dataframe=dataframe.dropna()
